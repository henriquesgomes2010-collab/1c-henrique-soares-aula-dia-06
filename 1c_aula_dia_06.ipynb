# %% [markdown]
# <a href="https://colab.research.google.com/github/henriquesgomes2010-collab/1c-henrique-soares-aula-dia-06/blob/main/1c_aula_dia_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada

Comprimento = 7 # metros
Largura = 4 # metros

# %%
# processamento

area = Comprimento * Largura

# %%
print (f"area total da sala é: {area} metros quadrados")
# Out:
# area total da sala é: 28 metros quadrados

# %%
# Entrada

Lado = 2
# processamento
resultado = Lado * Lado
# saida
print (f"resultado do quadrado é : {resultado}")
# Out:
# resultado do quadrado é : 4

# %%
# Entrada

numero = 3

# processamento

dobro = numero * 2

# Saida

print (f"o dobro do numero digitado é : {dobro}")
# Out:
# o dobro do numero digitado é : 6

# %% [markdown]
# escrever um algoritimo e o programa que receba 4 notas do aluno e calcula a média dessas notas e mostre a média

# %%
# entrada

a = float (input ("digite a nota: "))
b = float (input ("digite a nota: "))
c = float (input ("digite a nota: "))
d = float (input ("digite a nota: "))

# processamento
média = (a + b + c + d) / 4
# saida
print (f"a média do aluno foi: {média}")
# Out:
# digite a nota: 5
# digite a nota: 5
# digite a nota: 5
# digite a nota: 10
# a média do aluno foi: 6.25
